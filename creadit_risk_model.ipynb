# %% [markdown]
# # Credit Risk Modelling

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Data Loading and Analyzing

# %%
df_customers = pd.read_csv("dataset/customers.csv")
df_loans = pd.read_csv("dataset/loans.csv")
df_bureau = pd.read_csv("dataset/bureau_data.csv")

# %%
df_customers.shape, df_loans.shape, df_bureau.shape
# Out:
# ((50000, 12), (50000, 15), (50000, 8))

# %%
df_customers.head(3)
# Out:
#   cust_id  age gender marital_status  ... years_at_current_address     city        state zipcode
# 0  C00001   44      M        Married  ...                       27    Delhi        Delhi  110001
# 1  C00002   38      M        Married  ...                        4  Chennai   Tamil Nadu  600001
# 2  C00003   46      F        Married  ...                       24  Kolkata  West Bengal  700001
#
# [3 rows x 12 columns]

# %%
df_loans.head(3)
# Out:
#   loan_id cust_id loan_purpose  loan_type  ...  bank_balance_at_application  disbursal_date  installment_start_dt  default
# 0  L00001  C00001         Auto    Secured  ...                       873386      2019-07-24            2019-08-10    False
# 1  L00002  C00002         Home    Secured  ...                       464100      2019-07-24            2019-08-15    False
# 2  L00003  C00003     Personal  Unsecured  ...                      1476042      2019-07-24            2019-08-21    False
#
# [3 rows x 15 columns]

# %% [markdown]
# ### Merging Data

# %%
df = pd.merge(df_customers, df_loans, on="cust_id")
df.head(3)
# Out:
#   cust_id  age gender marital_status  ... bank_balance_at_application  disbursal_date  installment_start_dt default
# 0  C00001   44      M        Married  ...                      873386      2019-07-24            2019-08-10   False
# 1  C00002   38      M        Married  ...                      464100      2019-07-24            2019-08-15   False
# 2  C00003   46      F        Married  ...                     1476042      2019-07-24            2019-08-21   False
#
# [3 rows x 26 columns]

# %%
df_bureau.head(3)
# Out:
#   cust_id  number_of_open_accounts  number_of_closed_accounts  ...  total_dpd  enquiry_count  credit_utilization_ratio
# 0  C00001                        1                          1  ...          0              3                         7
# 1  C00002                        3                          1  ...         60              5                         4
# 2  C00003                        2                          1  ...        147              6                        58
#
# [3 rows x 8 columns]

# %%
df = pd.merge(df, df_bureau)
df.head(3)
# Out:
#   cust_id  age gender marital_status  ... delinquent_months  total_dpd  enquiry_count credit_utilization_ratio
# 0  C00001   44      M        Married  ...                 0          0              3                        7
# 1  C00002   38      M        Married  ...                12         60              5                        4
# 2  C00003   46      F        Married  ...                24        147              6                       58
#
# [3 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 33 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   cust_id                      50000 non-null  object
#  1   age                          50000 non-null  int64
#  2   gender                       50000 non-null  object
#  3   marital_status               50000 non-null  object
#  4   employment_status            50000 non-null  object
#  5   income                       50000 non-null  int64
#  6   number_of_dependants         50000 non-null  int64
#  7   residence_type               49938 non-null  object
#  8   years_at_current_address     50000 non-null  int64
#  9   city                         50000 non-null  object
#  10  state                        50000 non-null  object
#  11  zipcode                      50000 non-null  int64
#  12  loan_id                      50000 non-null  object
#  13  loan_purpose                 50000 non-null  object
#  14  loan_type                    50000 non-null  object
#  15  sanction_amount              50000 non-null  int64
#  16  loan_amount                  50000 non-null  int64
#  17  processing_fee               50000 non-null  float64
#  18  gst                          50000 non-null  int64
#  19  net_disbursement             50000 non-null  int64
#  20  loan_tenure_months           50000 non-null  int64
#  21  principal_outstanding        50000 non-null  int64
#  22  bank_balance_at_application  50000 non-null  int64
#  23  disbursal_date               50000 non-null  object
#  24  installment_start_dt         50000 non-null  object
#  25  default                      50000 non-null  bool
#  26  number_of_open_accounts      50000 non-null  int64
#  27  number_of_closed_accounts    50000 non-null  int64
#  28  total_loan_months            50000 non-null  int64
#  29  delinquent_months            50000 non-null  int64
#  30  total_dpd                    50000 non-null  int64
#  31  enquiry_count                50000 non-null  int64
#  32  credit_utilization_ratio     50000 non-null  int64
# dtypes: bool(1), float64(1), int64(19), object(12)
# memory usage: 12.3+ MB

# %% [markdown]
# #### Converting DEFAULT column from boolean to int

# %%
df['default'] = df['default'].astype(int)
df.default.value_counts()
# Out:
# default
# 0    45703
# 1     4297
# Name: count, dtype: int64

# %% [markdown]
# ## Split dataset into Train and Test besfore Training to avoid Data Leakage

# %%
X = df.drop("default", axis="columns")
y = df["default"]

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.25, random_state=42)

df_train = pd.concat([X_train, y_train], axis='columns')
df_test = pd.concat([X_test, y_test], axis='columns')

# %%
df_train.head(3)
# Out:
#       cust_id  age gender marital_status  ... total_dpd  enquiry_count  credit_utilization_ratio default
# 12746  C12747   59      M        Married  ...       118              4                        36       0
# 32495  C32496   44      F         Single  ...        62              5                         5       0
# 43675  C43676   38      M         Single  ...        67              4                         0       0
#
# [3 rows x 33 columns]

# %%
df_train.shape, df_test.shape
# Out:
# ((37500, 33), (12500, 33))

# %% [markdown]
# ### Data Cleaning
